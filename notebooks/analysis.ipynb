# %% [markdown]
# # Analyzing Students' Mental Health
#
# ## Project Overview
# The goal of this project is to analyze the mental health of international students using data analysis techniques. We will use **SQL** to query data and **Python (Pandas, Plotly)** to visualize the results. Key areas of focus include depression scores, social connectivity, and acculturative stress.
#
# ### Objectives
# 1. Formulate analytical questions.
# 2. Consult data using SQL.
# 3. Bridge SQL and Python for analysis.
# 4. Visualize and interpret findings.

# %% [markdown]
# ## 1. Setup and Configuration
# Installing necessary libraries and configuring the visual theme for the notebook.

# %%
# Install dependencies (if not already installed)
# %pip install -r ../requirements.txt

# Import Libraries
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
from sqlalchemy import create_engine
# Out:
# Requirement already satisfied: jupyter in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pandas in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: sqlalchemy in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (2.0.46)
# Requirement already satisfied: psycopg2-binary in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (2.9.11)
# Requirement already satisfied: jupysql in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (0.11.1)
# Requirement already satisfied: plotly in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (6.5.2)
# Requirement already satisfied: notebook in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (7.5.2)
# Requirement already satisfied: jupyter-console in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: ipywidgets in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter->-r ../requirements.txt (line 1)) (4.5.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: greenlet>=1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from sqlalchemy->-r ../requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from sqlalchemy->-r ../requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: sqlparse in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (28.6.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupysql->-r ../requirements.txt (line 5)) (0.2.27)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from plotly->-r ../requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: packaging in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from plotly->-r ../requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyyaml in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (7.6.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql->-r ../requirements.txt (line 5)) (2026.1.4)
# Requirement already satisfied: wcwidth in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from prettytable>=3.12.0->jupysql->-r ../requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r ../requirements.txt (line 1)) (4.5.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jinja2->jupysql->-r ../requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 1)) (80.10.1)
# Requirement already satisfied: anyio in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0b1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sebas\documents\dev\analyzing-students-mental-health-in-sql\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 1)) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Load and Inspect Data
# We start by loading the dataset to understand its structure and content.

# %%
df = pd.read_csv('../data/students.csv')
df.head()
# Out:
#   inter_dom Region  Gender Academic   Age  Age_cate  Stay Stay_Cate  Japanese  \
# 0     Inter    SEA    Male     Grad  24.0       4.0   5.0      Long       3.0
# 1     Inter    SEA    Male     Grad  28.0       5.0   1.0     Short       4.0
# 2     Inter    SEA    Male     Grad  25.0       4.0   6.0      Long       4.0
# 3     Inter     EA  Female     Grad  29.0       5.0   1.0     Short       2.0
# 4     Inter     EA  Female     Grad  28.0       5.0   1.0     Short       1.0
#
#   Japanese_cate  ...  Friends_bi Parents_bi Relative_bi Professional_bi  \
# 0       Average  ...         Yes        Yes          No              No
# 1          High  ...         Yes        Yes          No              No
# 2          High  ...          No         No          No              No
# 3           Low  ...         Yes        Yes         Yes             Yes
# 4           Low  ...         Yes        Yes          No             Yes
#
#   Phone_bi Doctor_bi religion_bi  Alone_bi Others_bi  Internet_bi
# 0       No        No          No        No        No           No
# 1       No        No          No        No        No           No
# 2       No        No          No        No        No           No
# 3       No        No          No        No        No           No
# 4       No       Yes         Yes        No        No           No
#
# [5 rows x 50 columns]

# %% [markdown]
# ## 3. SQL Database Setup
# We will establish a connection to the local PostgreSQL database to enable SQL-based querying.

# %%
# Create SQLAlchemy Engine
engine = create_engine("postgresql://students_db:postgres@localhost:5432/students_db")

# Write DataFrame to SQL (Replace if exists)
df.to_sql(
    name='students',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 286

# %% [markdown]
# ### SQL Extension Setup
# Using `jupysql` to run SQL queries directly in notebook cells.

# %%
# %load_ext sql
# %sql postgresql+psycopg2://students_db:postgres@localhost:5432/students_db
# Out:
# Connecting to 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'

# %%
# %%sql
# SELECT *
# FROM students
# LIMIT 5;
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 5 rows affected.
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# | inter_dom | Region | Gender | Academic | Age  | Age_cate | Stay | Stay_Cate | Japanese | Japanese_cate | English | English_cate | Intimate | Religion | Suicide | Dep | DepType | ToDep | DepSev | ToSC | APD  | AHome | APH  | Afear | ACS  | AGuilt | AMiscell | ToAS | Partner | Friends | Parents | Relative | Profess |  Phone | Doctor | Reli | Alone | Others | Internet | Partner_bi | Friends_bi | Parents_bi | Relative_bi | Professional_bi | Phone_bi | Doctor_bi | religion_bi | Alone_bi | Others_bi | Internet_bi |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# |   Inter   |  SEA   |  Male  |   Grad   | 24.0 |   4.0    | 5.0  |    Long   |   3.0    |    Average    |   5.0   |     High     |   None   |   Yes    |    No   |  No |    No   |  0.0  |  Min   | 34.0 | 23.0 |  9.0  | 11.0 |  8.0  | 11.0 |  2.0   |   27.0   | 91.0 |   5.0   |   5.0   |   6.0   |   3.0    |   2.0   |  1.0   |  4.0   | 1.0  |  3.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   |  Male  |   Grad   | 28.0 |   5.0    | 1.0  |   Short   |   4.0    |      High     |   4.0   |     High     |   None   |    No    |    No   |  No |    No   |  2.0  |  Min   | 48.0 | 8.0  |  7.0  | 5.0  |  4.0  | 3.0  |  2.0   |   10.0   | 39.0 |   7.0   |   7.0   |   7.0   |   4.0    |   4.0   |  4.0   |  4.0   | 1.0  |  1.0  |  1.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   |  Male  |   Grad   | 25.0 |   4.0    | 6.0  |    Long   |   4.0    |      High     |   4.0   |     High     |   Yes    |   Yes    |    No   |  No |    No   |  2.0  |  Min   | 41.0 | 13.0 |  4.0  | 7.0  |  6.0  | 4.0  |  3.0   |   14.0   | 51.0 |   3.0   |   3.0   |   3.0   |   1.0    |   1.0   |  2.0   |  1.0   | 1.0  |  1.0  |  1.0   |   None   |     No     |     No     |     No     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |   EA   | Female |   Grad   | 29.0 |   5.0    | 1.0  |   Short   |   2.0    |      Low      |   3.0   |   Average    |    No    |    No    |    No   |  No |    No   |  3.0  |  Min   | 37.0 | 16.0 |  10.0 | 10.0 |  8.0  | 6.0  |  4.0   |   21.0   | 75.0 |   5.0   |   5.0   |   5.0   |   5.0    |   5.0   |  2.0   |  2.0   | 2.0  |  4.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |     Yes     |       Yes       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |   EA   | Female |   Grad   | 28.0 |   5.0    | 1.0  |   Short   |   1.0    |      Low      |   3.0   |   Average    |   Yes    |    No    |    No   |  No |    No   |  3.0  |  Min   | 37.0 | 15.0 |  12.0 | 5.0  |  8.0  | 7.0  |  4.0   |   31.0   | 82.0 |   5.0   |   5.0   |   5.0   |   2.0    |   5.0   |  2.0   |  5.0   | 5.0  |  4.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |       Yes       |    No    |    Yes    |     Yes     |    No    |     No    |      No     |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+

# %% [markdown]
# ## 4. Demographics & Data Overview
# **Key Questions:**
# *   How many International vs. Domestic students are there?
# *   What is in the unassigned rows?
# *   Where do the international students come from?

# %%
# %%sql
# SELECT inter_dom, count(*) as count_inter_dom
# FROM students
# WHERE inter_dom IS NOT NULL OR inter_dom = ''
# GROUP BY inter_dom;
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 2 rows affected.
# +-----------+-----------------+
# | inter_dom | count_inter_dom |
# +-----------+-----------------+
# |    Dom    |        67       |
# |   Inter   |       201       |
# +-----------+-----------------+

# %%
result = _
df_inter_vs_dom = result.DataFrame()

fig1 = px.bar(
    df_inter_vs_dom,
    x="inter_dom",
    y="count_inter_dom",
    color="inter_dom",
    title="Student Composition by Type",
    labels={
        "inter_dom": "Type of Student",
        "count_inter_dom": "Number of Students"
    }
)

fig1.show()

# %%
# %%sql
# -- Inspect 'Unassigned' rows (where inter_dom is NULL or empty)
# SELECT *
# FROM students
# WHERE inter_dom IS NULL OR inter_dom = '';
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 18 rows affected.
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+------+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# | inter_dom | Region | Gender | Academic | Age  | Age_cate | Stay | Stay_Cate | Japanese | Japanese_cate | English | English_cate | Intimate | Religion | Suicide | Dep  | DepType | ToDep | DepSev | ToSC | APD  | AHome | APH  | Afear | ACS  | AGuilt | AMiscell | ToAS | Partner | Friends | Parents | Relative | Profess |  Phone | Doctor | Reli | Alone | Others | Internet | Partner_bi | Friends_bi | Parents_bi | Relative_bi | Professional_bi | Phone_bi | Doctor_bi | religion_bi | Alone_bi | Others_bi | Internet_bi |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+------+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |  None  | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    None    |    None    |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  |  96  |    42   |  None |   65   | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    145     |    128     |    137     |      66     |        61       |    30    |     46    |      19     |    65    |     21    |      45     |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | 172  |    54   |  None |  107   | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    123     |    140     |    131     |     202     |       207       |   238    |    222    |     249     |   203    |    247    |     223     |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   172   |  None |   73   | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    None    |    None    |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |   15   | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    145     |    128     |    137     |      66     |        61       |    30    |     46    |      19     |    65    |     21    |      45     |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |   8    | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    123     |    140     |    131     |     202     |       207       |   238    |    222    |     249     |   203    |    247    |     223     |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |  None  | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    None    |    None    |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |  None  | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    145     |    123     |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |  None  | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    128     |    140     |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# |    None   |  None  |  None  |   None   | None |   None   | None |    None   |   None   |      None     |   None  |     None     |   None   |   None   |   None  | None |   None  |  None |  None  | None | None |  None | None |  None | None |  None  |   None   | None |   None  |   None  |   None  |   None   |   None  |  None  |  None  | None |  None |  None  |   None   |    137     |    131     |    None    |     None    |       None      |   None   |    None   |     None    |   None   |    None   |     None    |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+------+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT "Region", COUNT(inter_dom) AS count_inter_dom
# FROM students
# WHERE inter_dom = 'Inter'
# GROUP BY "Region";
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 5 rows affected.
# +--------+-----------------+
# | Region | count_inter_dom |
# +--------+-----------------+
# |   EA   |        48       |
# |  JAP   |        2        |
# | Others |        11       |
# |   SA   |        18       |
# |  SEA   |       122       |
# +--------+-----------------+

# %%
result = _
df_inter_students = result.DataFrame()

# Bar chart
fig2 = px.bar(
    df_inter_students,
    x='Region',
    y='count_inter_dom',
    color='Region',
    title='Region of Origin of International Students',
    labels={
        'Region of Origin': 'Region of Origin',
        'Number of Students': 'Number of Students'
    }
)

fig2.show()

# %% [markdown]
# ## 5. Psychometric Distributions (PHQ-9, SCS, ASISS)
# **Key Questions:**
# *   What are the Min, Max, and Average scores for:
#     *   **PHQ-9 (Depression):** `todep`
#     *   **SCS (Social Connectedness):** `tosc`
#     *   **ASISS (Acculturative Stress):** `toas`

# %%
# %%sql
# SELECT
#     MIN("ToDep") AS min_phq,
#     MAX("ToDep") AS max_phq,
#     ROUND(AVG("ToDep")::numeric, 2) AS avg_phq,
#
#     MIN("ToSC") AS min_scs,
#     MAX("ToSC") AS max_scs,
#     ROUND(AVG("ToSC")::numeric, 2) AS avg_scs,
#
#     MIN("ToAS") AS min_as,
#     MAX("ToAS") AS max_as,
#     ROUND(AVG("ToAS")::numeric, 2) AS avg_as
# FROM students;
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 1 rows affected.
# +---------+---------+---------+---------+---------+---------+--------+--------+--------+
# | min_phq | max_phq | avg_phq | min_scs | max_scs | avg_scs | min_as | max_as | avg_as |
# +---------+---------+---------+---------+---------+---------+--------+--------+--------+
# |   0.0   |   25.0  |   8.19  |   8.0   |   48.0  |  37.47  |  36.0  | 145.0  | 72.38  |
# +---------+---------+---------+---------+---------+---------+--------+--------+--------+

# %%
# %%sql
# SELECT * FROM students;
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 286 rows affected.
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+-------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# | inter_dom | Region | Gender | Academic | Age  | Age_cate | Stay | Stay_Cate | Japanese | Japanese_cate | English | English_cate | Intimate | Religion | Suicide | Dep | DepType | ToDep | DepSev | ToSC | APD  | AHome | APH  | Afear | ACS  | AGuilt | AMiscell |  ToAS | Partner | Friends | Parents | Relative | Profess |  Phone | Doctor | Reli | Alone | Others | Internet | Partner_bi | Friends_bi | Parents_bi | Relative_bi | Professional_bi | Phone_bi | Doctor_bi | religion_bi | Alone_bi | Others_bi | Internet_bi |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+-------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# |   Inter   |  SEA   |  Male  |   Grad   | 24.0 |   4.0    | 5.0  |    Long   |   3.0    |    Average    |   5.0   |     High     |   None   |   Yes    |    No   |  No |    No   |  0.0  |  Min   | 34.0 | 23.0 |  9.0  | 11.0 |  8.0  | 11.0 |  2.0   |   27.0   |  91.0 |   5.0   |   5.0   |   6.0   |   3.0    |   2.0   |  1.0   |  4.0   | 1.0  |  3.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   |  Male  |   Grad   | 28.0 |   5.0    | 1.0  |   Short   |   4.0    |      High     |   4.0   |     High     |   None   |    No    |    No   |  No |    No   |  2.0  |  Min   | 48.0 | 8.0  |  7.0  | 5.0  |  4.0  | 3.0  |  2.0   |   10.0   |  39.0 |   7.0   |   7.0   |   7.0   |   4.0    |   4.0   |  4.0   |  4.0   | 1.0  |  1.0  |  1.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   |  Male  |   Grad   | 25.0 |   4.0    | 6.0  |    Long   |   4.0    |      High     |   4.0   |     High     |   Yes    |   Yes    |    No   |  No |    No   |  2.0  |  Min   | 41.0 | 13.0 |  4.0  | 7.0  |  6.0  | 4.0  |  3.0   |   14.0   |  51.0 |   3.0   |   3.0   |   3.0   |   1.0    |   1.0   |  2.0   |  1.0   | 1.0  |  1.0  |  1.0   |   None   |     No     |     No     |     No     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |   EA   | Female |   Grad   | 29.0 |   5.0    | 1.0  |   Short   |   2.0    |      Low      |   3.0   |   Average    |    No    |    No    |    No   |  No |    No   |  3.0  |  Min   | 37.0 | 16.0 |  10.0 | 10.0 |  8.0  | 6.0  |  4.0   |   21.0   |  75.0 |   5.0   |   5.0   |   5.0   |   5.0    |   5.0   |  2.0   |  2.0   | 2.0  |  4.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |     Yes     |       Yes       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |   EA   | Female |   Grad   | 28.0 |   5.0    | 1.0  |   Short   |   1.0    |      Low      |   3.0   |   Average    |   Yes    |    No    |    No   |  No |    No   |  3.0  |  Min   | 37.0 | 15.0 |  12.0 | 5.0  |  8.0  | 7.0  |  4.0   |   31.0   |  82.0 |   5.0   |   5.0   |   5.0   |   2.0    |   5.0   |  2.0   |  5.0   | 5.0  |  4.0  |  4.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |       Yes       |    No    |    Yes    |     Yes     |    No    |     No    |      No     |
# |   Inter   |  SEA   |  Male  |   Grad   | 24.0 |   4.0    | 6.0  |    Long   |   3.0    |    Average    |   4.0   |     High     |   Yes    |    No    |    No   |  No |    No   |  6.0  |  Mild  | 38.0 | 18.0 |  8.0  | 10.0 |  8.0  | 7.0  |  3.0   |   29.0   |  83.0 |   6.0   |   5.0   |   4.0   |   2.0    |   1.0   |  1.0   |  2.0   | 1.0  |  5.0  |  1.0   |   None   |    Yes     |    Yes     |     No     |      No     |        No       |    No    |     No    |      No     |   Yes    |     No    |      No     |
# |   Inter   |   SA   |  Male  |   Grad   | 23.0 |   4.0    | 1.0  |   Short   |   3.0    |    Average    |   5.0   |     High     |   Yes    |    No    |    No   |  No |    No   |  3.0  |  Min   | 46.0 | 17.0 |  6.0  | 10.0 |  5.0  | 3.0  |  2.0   |   15.0   |  58.0 |   7.0   |   5.0   |   7.0   |   2.0    |   2.0   |  1.0   |  5.0   | 1.0  |  1.0  |  1.0   |   None   |    Yes     |    Yes     |    Yes     |      No     |        No       |    No    |    Yes    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   | Female |   Grad   | 30.0 |   5.0    | 2.0  |   Medium  |   1.0    |      Low      |   1.0   |     Low      |   Yes    |   Yes    |   Yes   |  No |    No   |  9.0  |  Mild  | 41.0 | 16.0 |  20.0 | 19.0 |  15.0 | 11.0 |  6.0   |   40.0   | 127.0 |   7.0   |   2.0   |   2.0   |   2.0    |   6.0   |  2.0   |  1.0   | 1.0  |  3.0  |  1.0   |   None   |    Yes     |     No     |     No     |      No     |       Yes       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   |  SEA   | Female |   Grad   | 25.0 |   4.0    | 4.0  |    Long   |   4.0    |      High     |   4.0   |     High     |    No    |    No    |    No   | Yes |  Other  |  7.0  |  Mild  | 36.0 | 22.0 |  12.0 | 13.0 |  13.0 | 10.0 |  6.0   |   33.0   | 109.0 |   4.0   |   4.0   |   4.0   |   4.0    |   4.0   |  4.0   |  4.0   | 4.0  |  4.0  |  4.0   |   None   |     No     |     No     |     No     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# |   Inter   | Others |  Male  |   Grad   | 31.0 |   5.0    | 2.0  |   Medium  |   1.0    |      Low      |   4.0   |     High     |   Yes    |   Yes    |    No   |  No |    No   |  3.0  |  Min   | 48.0 | 8.0  |  4.0  | 5.0  |  12.0 | 3.0  |  2.0   |   17.0   |  51.0 |   1.0   |   1.0   |   1.0   |   2.0    |   1.0   |  1.0   |  2.0   | 1.0  |  2.0  |  1.0   |   None   |     No     |     No     |     No     |      No     |        No       |    No    |     No    |      No     |    No    |     No    |      No     |
# +-----------+--------+--------+----------+------+----------+------+-----------+----------+---------------+---------+--------------+----------+----------+---------+-----+---------+-------+--------+------+------+-------+------+-------+------+--------+----------+-------+---------+---------+---------+----------+---------+--------+--------+------+-------+--------+----------+------------+------------+------------+-------------+-----------------+----------+-----------+-------------+----------+-----------+-------------+
# Truncated to displaylimit of 10.

# %%
result = _
df_all = result.DataFrame()

psycho_melted = df_all.melt(
    id_vars=["inter_dom", "Age"],
    value_vars=["ToDep", "ToSC", "ToAS"],
    var_name="Test",
    value_name="Score"
)

fig3 = px.box(
    psycho_melted,
    x="Score",
    y="Test",
    color="inter_dom",
    points="all",
    hover_data=["Age"],
    title="Distribution of Psychometric Scores by Student Type",
    labels={
        "inter_dom": "Type of Student",
        "Score": "Score",
        "Test": "Psychometric Test"
    }
)
fig3.show()

# %% [markdown]
# ## 6. Comparative Analysis
# **Key Questions:**
# *   How do Domestic vs. International students differ in scores?
# *   Does Age influence mental health scores?
# *   Does Length of Stay influence mental health?

# %%
# %%sql
# -- Average Scores by Student Type
# SELECT
#     inter_dom,
#     ROUND(AVG("ToDep")::numeric, 2) as avg_depression,
#     ROUND(AVG("ToSC")::numeric, 2) as avg_social_connectedness,
#     ROUND(AVG("ToAS")::numeric, 2) as avg_acculturative_stress
# FROM students
# WHERE inter_dom IS NOT NULL
# GROUP BY inter_dom;
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 2 rows affected.
# +-----------+----------------+--------------------------+--------------------------+
# | inter_dom | avg_depression | avg_social_connectedness | avg_acculturative_stress |
# +-----------+----------------+--------------------------+--------------------------+
# |    Dom    |      8.61      |          37.64           |          62.84           |
# |   Inter   |      8.04      |          37.42           |          75.56           |
# +-----------+----------------+--------------------------+--------------------------+

# %%
result = _
df_avg = result.DataFrame()

df_melted = df_avg.melt(
    id_vars="inter_dom",
    value_vars=[
        "avg_depression",
        "avg_social_connectedness",
        "avg_acculturative_stress"
    ],
    var_name="Metric",
    value_name="Average Score"
)

label_map = {
    "avg_depression": "Depression (PHQ-9)",
    "avg_social_connectedness": "Social Connectedness (SCS)",
    "avg_acculturative_stress": "Acculturative Stress (ASISS)"
}

df_melted["Metric"] = df_melted["Metric"].map(label_map)

fig4 = px.bar(
    df_melted,
    x="Metric",
    y="Average Score",
    color="inter_dom",
    barmode="group",
    title="Average Psychometric Scores by Student Type",
    labels={
        "inter_dom": "Type of Student",
        "Metric": "Psychometric Measure",
        "Average Score": "Average Score"
    }
)

fig4.show()

# %% [markdown]
# ## 7. Factors Influencing Depression
# **Key Questions:**
# *   Is there a gender difference in depression?
# *   Does Japanese language proficiency or Social connectedness affect depression?
# *   What help-seeking resources are preferred?

# %%
# %%sql
# -- Average Depression by Gender
# SELECT "Gender", ROUND(AVG("ToDep")::numeric, 2) as avg_depression
# FROM students
# WHERE inter_dom IS NOT NULL
# GROUP BY "Gender";
# Out:
# Running query in 'postgresql+psycopg2://students_db:***@localhost:5432/students_db'
# 2 rows affected.
# +--------+----------------+
# | Gender | avg_depression |
# +--------+----------------+
# |  Male  |      7.82      |
# | Female |      8.40      |
# +--------+----------------+

# %%
result = _
df_avg_genre = result.DataFrame()

fig5 = px.bar(
    df_avg_genre,
    x='Gender',
    y='avg_depression',
    color='Gender',
    title='Average Depression Score by Gender',
    labels={
        'Gender': 'Gender',
        'avg_depression': 'Average Depression Score'
    }
)

fig5.show()
